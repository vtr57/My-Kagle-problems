# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df = df[['PassengerId',
 'Pclass',
 'Name',
 'Sex',
 'Age',
 'SibSp',
 'Parch',
 'Ticket',
 'Fare',
 'Cabin',
 'Embarked',
'Survived']]

# %%
df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
X = df[['PassengerId',
 'Pclass',
 'Name',
 'Sex',
 'Age',
 'SibSp',
 'Parch',
 'Ticket',
 'Fare',
 'Cabin',
 'Embarked']]

# %%
X.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
y = df.drop(['PassengerId',
 'Pclass',
 'Name',
 'Sex',
 'Age',
 'SibSp',
 'Parch',
 'Ticket',
 'Fare',
 'Cabin',
 'Embarked'], axis=1)

# %%
y.head()
# Out:
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
X = X.drop(['Name'], axis=1)
X = X.drop(['Ticket'], axis=1)

# %%
X.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0            1       3    male  22.0      1      0   7.2500   NaN        S
# 1            2       1  female  38.0      1      0  71.2833   C85        C
# 2            3       3  female  26.0      0      0   7.9250   NaN        S
# 3            4       1  female  35.0      1      0  53.1000  C123        S
# 4            5       3    male  35.0      0      0   8.0500   NaN        S

# %%
X['Sex'].replace(['male', 'female'],
                        [0, 1], inplace=True)

# %%
X.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0            1       3    0  22.0      1      0   7.2500   NaN        S
# 1            2       1    1  38.0      1      0  71.2833   C85        C
# 2            3       3    1  26.0      0      0   7.9250   NaN        S
# 3            4       1    1  35.0      1      0  53.1000  C123        S
# 4            5       3    0  35.0      0      0   8.0500   NaN        S

# %%
X['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
X['Embarked'].replace(['S', 'C', 'Q'],
                        [0, 1,2], inplace=True)

# %%
X.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare Cabin  Embarked
# 0            1       3    0  22.0      1      0   7.2500   NaN       0.0
# 1            2       1    1  38.0      1      0  71.2833   C85       1.0
# 2            3       3    1  26.0      0      0   7.9250   NaN       0.0
# 3            4       1    1  35.0      1      0  53.1000  C123       0.0
# 4            5       3    0  35.0      0      0   8.0500   NaN       0.0

# %%
X['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
X['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
X['Age'].fillna(X['Age'].mean(), inplace = True)

# %%
X['Age'].unique()
# Out:
# array([22.        , 38.        , 26.        , 35.        , 29.69911765,
#        54.        ,  2.        , 27.        , 14.        ,  4.        ,
#        58.        , 20.        , 39.        , 55.        , 31.        ,
#        34.        , 15.        , 28.        ,  8.        , 19.        ,
#        40.        , 66.        , 42.        , 21.        , 18.        ,
#         3.        ,  7.        , 49.        , 29.        , 65.        ,
#        28.5       ,  5.        , 11.        , 45.        , 17.        ,
#        32.        , 16.        , 25.        ,  0.83      , 30.        ,
#        33.        , 23.        , 24.        , 46.        , 59.        ,
#        71.        , 37.        , 47.        , 14.5       , 70.5       ,
#        32.5       , 12.        ,  9.        , 36.5       , 51.        ,
#        55.5       , 40.5       , 44.        ,  1.        , 61.        ,
#        56.        , 50.        , 36.        , 45.5       , 20.5       ,
# ...

# %%
X['Embarked'].unique()
# Out:
# array([ 0.,  1.,  2., nan])

# %% [markdown]
# #### Há nan na coluna Cabin.

# %%
X[X['Embarked'].isnull()==True]
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch  Fare Cabin  Embarked
# 61            62       1    1  38.0      0      0  80.0   B28       NaN
# 829          830       1    1  62.0      0      0  80.0   B28       NaN

# %%
X.drop([61, 829], inplace=True)

# %%
y.drop([61, 829], inplace=True)

# %%
XsemCabin = X.drop(['Cabin', 'PassengerId'], axis=1)

# %%
XsemCabin
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    0  22.000000      1      0   7.2500       0.0
# 1         1    1  38.000000      1      0  71.2833       1.0
# 2         3    1  26.000000      0      0   7.9250       0.0
# 3         1    1  35.000000      1      0  53.1000       0.0
# 4         3    0  35.000000      0      0   8.0500       0.0
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    0  27.000000      0      0  13.0000       0.0
# 887       1    1  19.000000      0      0  30.0000       0.0
# 888       3    1  29.699118      1      2  23.4500       0.0
# 889       1    0  26.000000      0      0  30.0000       1.0
# 890       3    0  32.000000      0      0   7.7500       2.0
#
# [889 rows x 7 columns]

# %%
XsemCabin.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  889.000000  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     2.311586    0.350956   29.653446    0.524184    0.382452   32.096681
# std      0.834700    0.477538   12.968366    1.103705    0.806761   49.697504
# min      1.000000    0.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000   22.000000    0.000000    0.000000    7.895800
# 50%      3.000000    0.000000   29.699118    0.000000    0.000000   14.454200
# 75%      3.000000    1.000000   35.000000    1.000000    0.000000   31.000000
# max      3.000000    1.000000   80.000000    8.000000    6.000000  512.329200
#
#          Embarked
# count  889.000000
# mean     0.362205
# std      0.636157
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      2.000000

# %% [markdown]
# ## Modelando por KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
modelo = KNeighborsClassifier(3)

# %%
modelo.fit(XsemCabin,y)
# Out:
# C:\Users\vitor\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3)

# %%
len(modelo.predict(XsemCabin))
# Out:
# 889

# %%
modelo.score(XsemCabin,y)
# Out:
# 0.8312710911136107

# %% [markdown]
# ## Pre processamento no teste

# %%
df_teste = pd.read_csv('test.csv')

# %%
df_teste.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
len(df_teste)
# Out:
# 418

# %%
df_teste = df_teste.drop(['Name'], axis=1)
df_teste = df_teste.drop(['Ticket'], axis=1)
df_teste['Sex'].replace(['male', 'female'],[0, 1], inplace=True)
df_teste['Embarked'].replace(['S', 'C', 'Q'], [0, 1,2], inplace=True)
df_teste['Age'].fillna(df_teste['Age'].mean(), inplace = True)

# %%
df_teste
# Out:
#      PassengerId  Pclass  Sex       Age  SibSp  Parch      Fare Cabin  \
# 0            892       3    0  34.50000      0      0    7.8292   NaN
# 1            893       3    1  47.00000      1      0    7.0000   NaN
# 2            894       2    0  62.00000      0      0    9.6875   NaN
# 3            895       3    0  27.00000      0      0    8.6625   NaN
# 4            896       3    1  22.00000      1      1   12.2875   NaN
# ..           ...     ...  ...       ...    ...    ...       ...   ...
# 413         1305       3    0  30.27259      0      0    8.0500   NaN
# 414         1306       1    1  39.00000      0      0  108.9000  C105
# 415         1307       3    0  38.50000      0      0    7.2500   NaN
# 416         1308       3    0  30.27259      0      0    8.0500   NaN
# 417         1309       3    0  30.27259      1      1   22.3583   NaN
#
#      Embarked
# 0           2
# 1           0
# 2           2
# 3           0
# 4           0
# ..        ...
# 413         0
# ...

# %%
df_teste = df_teste.drop(['Cabin', 'PassengerId'], axis=1)

# %%
XsemCabin
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    0  22.000000      1      0   7.2500       0.0
# 1         1    1  38.000000      1      0  71.2833       1.0
# 2         3    1  26.000000      0      0   7.9250       0.0
# 3         1    1  35.000000      1      0  53.1000       0.0
# 4         3    0  35.000000      0      0   8.0500       0.0
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    0  27.000000      0      0  13.0000       0.0
# 887       1    1  19.000000      0      0  30.0000       0.0
# 888       3    1  29.699118      1      2  23.4500       0.0
# 889       1    0  26.000000      0      0  30.0000       1.0
# 890       3    0  32.000000      0      0   7.7500       2.0
#
# [889 rows x 7 columns]

# %%
df_teste
# Out:
#      Pclass  Sex        Age  SibSp  Parch      Fare  Embarked
# 0         3    0  34.500000      0      0    7.8292         2
# 1         3    1  47.000000      1      0    7.0000         0
# 2         2    0  62.000000      0      0    9.6875         2
# 3         3    0  27.000000      0      0    8.6625         0
# 4         3    1  22.000000      1      1   12.2875         0
# ..      ...  ...        ...    ...    ...       ...       ...
# 413       3    0  29.653446      0      0    8.0500         0
# 414       1    1  39.000000      0      0  108.9000         1
# 415       3    0  38.500000      0      0    7.2500         0
# 416       3    0  29.653446      0      0    8.0500         0
# 417       3    0  29.653446      1      1   22.3583         1
#
# [418 rows x 7 columns]

# %%
df_teste['Fare'].unique()
# Out:
# array([  7.8292    ,   7.        ,   9.6875    ,   8.6625    ,
#         12.2875    ,   9.225     ,   7.6292    ,  29.        ,
#          7.2292    ,  24.15      ,   7.8958    ,  26.        ,
#         82.2667    ,  61.175     ,  27.7208    ,  12.35      ,
#          7.225     ,   7.925     ,  59.4       ,   3.1708    ,
#         31.6833    ,  61.3792    , 262.375     ,  14.5       ,
#         61.9792    ,  30.5       ,  21.6792    ,  31.5       ,
#         20.575     ,  23.45      ,  57.75      ,   8.05      ,
#          9.5       ,  56.4958    ,  13.4167    ,  26.55      ,
#          7.85      ,  13.        ,  52.5542    ,  29.7       ,
#          7.75      ,  76.2917    ,  15.9       ,  60.        ,
#         15.0333    ,  23.        , 263.        ,  15.5792    ,
#         29.125     ,   7.65      ,  16.1       ,  13.5       ,
#          7.725     ,  21.        ,   7.8792    ,  42.4       ,
#         28.5375    , 211.5       ,  25.7       ,  15.2458    ,
# ...

# %%
df_teste[df_teste['Fare'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]
# Index: []

# %%
df_teste['Fare'].fillna(df_teste['Fare'].mean(), inplace = True)

# %% [markdown]
# ## Testando o modelo

# %%
previsao = modelo.predict(df_teste)

# %%
len(previsao)
# Out:
# 418

# %%
gender_submission1 = pd.DataFrame({'PassengerId': list(range(892, 892+418)), 'Survived': previsao})

# %%
gender_submission1
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         1
# 3            895         1
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
gender_submission1.to_csv('gender_submission1.csv', index=False)
